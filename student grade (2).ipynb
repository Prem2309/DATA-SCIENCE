# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\Prem Panchal\Documents\studentgrade.xlsx")

# %%
df
# Out:
#    Student_Id  Age Grade
# 0         101   20     A
# 1         102   21     B
# 2         103   22     A
# 3         104   19     C

# %%
import pandas as pd
dc=pd.read_excel(r"C:\Users\Prem Panchal\Documents\studentmarks.xlsx")

# %%
dc
# Out:
#    Student_Id     Name  Marks
# 0         101    Alice     85
# 1         102      Bob     90
# 2         103  Charlie     88
# 3         104    David     92

# %%
#Mergeing using right join
merged_df=pd.merge(dc,df,on='Student_Id',how='right')

# %%
merged_df
# Out:
#    Student_Id   Name_x  Marks_x   Name_y  Marks_y
# 0         101    Alice       85    Alice       85
# 1         102      Bob       90      Bob       90
# 2         103  Charlie       88  Charlie       88
# 3         104    David       92    David       92

# %%
merged_df=pd.merge(dc,df,on='Student_Id',how='left')

# %%
merged_df
# Out:
#    Student_Id   Name_x  Marks_x   Name_y  Marks_y
# 0         101    Alice       85    Alice       85
# 1         102      Bob       90      Bob       90
# 2         103  Charlie       88  Charlie       88
# 3         104    David       92    David       92

# %%
#merging using inner join
merged_df=pd.merge(dc,df,on ='Student_Id',how='inner')

# %%
merged_df
# Out:
#    Student_Id   Name_x  Marks_x   Name_y  Marks_y
# 0         101    Alice       85    Alice       85
# 1         102      Bob       90      Bob       90
# 2         103  Charlie       88  Charlie       88
# 3         104    David       92    David       92

# %%
#merging using outer join
merged_df=pd.merge(dc,df,on='Student_Id',how='outer')

# %%
merged_df
# Out:
#    Student_Id   Name_x  Marks_x   Name_y  Marks_y
# 0         101    Alice       85    Alice       85
# 1         102      Bob       90      Bob       90
# 2         103  Charlie       88  Charlie       88
# 3         104    David       92    David       92

# %%
merged_df.set_index('Student_Id', inplace=True)
merged_df
# Out:
#              Name_x  Marks_x   Name_y  Marks_y
# Student_Id
# 101           Alice       85    Alice       85
# 102             Bob       90      Bob       90
# 103         Charlie       88  Charlie       88
# 104           David       92    David       92

# %%
#index reset as previous
merged_df.reset_index('Student_Id', inplace=True)
merged_df
# Out:
#    Student_Id   Name_x  Marks_x   Name_y  Marks_y
# 0         101    Alice       85    Alice       85
# 1         102      Bob       90      Bob       90
# 2         103  Charlie       88  Charlie       88
# 3         104    David       92    David       92

# %%
merged_df.to_csv('outer.csv',index=False)
merged_df
# Out:
#    Student_Id   Name_x  Marks_x   Name_y  Marks_y
# 0         101    Alice       85    Alice       85
# 1         102      Bob       90      Bob       90
# 2         103  Charlie       88  Charlie       88
# 3         104    David       92    David       92
